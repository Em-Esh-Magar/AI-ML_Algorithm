# %% [markdown]
# <a href="https://colab.research.google.com/github/Em-Esh-Magar/AI-ML_Algorithm/blob/main/Linear_Regression/AI_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'year':[1900,1910,1920,1930,1940],
    'price':[250,375,425,500,690]
}

# %%
data
# Out:
# {'year': [1900, 1910, 1920, 1930, 1940], 'price': [250, 375, 425, 500, 690]}

# %%
df = pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    5 non-null      int64
#  1   price   5 non-null      int64
# dtypes: int64(2)
# memory usage: 212.0 bytes

# %%
df.head()
# Out:
#    year  price
# 0  1900    250
# 1  1910    375
# 2  1920    425
# 3  1930    500
# 4  1940    690

# %%
plt.scatter(df['year'],df['price'])

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
input_data = df['year'].values.reshape(-1,1)
output_data = df['price'].values.reshape(-1,1)

# %%
model.fit(input_data,output_data)
# Out:
# LinearRegression()

# %%
model.predict([[1990]])
# Out:
# array([[1151.5]])

# %%
plt.scatter(df['year'],df['price'])
plt.plot(input_data,model.predict(input_data),color='red')
plt.show()
